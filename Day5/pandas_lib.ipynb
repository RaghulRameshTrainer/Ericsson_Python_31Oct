# %%
import pandas as pd
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)

# %%
df=pd.read_csv(r'C:\Users\DELL\Downloads\company.csv')

# %%
df
# Out:
#      Company   Age  Salary     Place Country  Gender
# 0        TCS  20.0     NaN   Chennai   India       0
# 1    Infosys  30.0     NaN    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]

# %%
df.head()
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %%
df.tail()
# Out:
#      Company   Age  Salary     Place Country  Gender
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0

# %%
df.head(10)
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0
# 5  Infosys   NaN  5000.0  Calcutta   India       0
# 6      TCS   NaN  6000.0   Chennai   India       1
# 7  Infosys  23.0  7000.0    Mumbai   India       1
# 8      TCS  34.0  8000.0  Calcutta   India       1
# 9      CTS  45.0  9000.0     Delhi   India       0

# %%
df
# Out:
#                        Company   Age  Salary       Place Country  Gender
# 0                          TCS  20.0     NaN     Chennai   India       0
# 1                      Infosys  30.0     NaN      Mumbai   India       0
# 2                          TCS  35.0  2300.0    Calcutta   India       0
# 3                      Infosys  40.0  3000.0       Delhi   India       0
# 4                          TCS  23.0  4000.0      Mumbai   India       0
# 5                      Infosys   NaN  5000.0    Calcutta   India       0
# 6                          TCS   NaN  6000.0     Chennai   India       1
# 7                      Infosys  23.0  7000.0      Mumbai   India       1
# 8                          TCS  34.0  8000.0    Calcutta   India       1
# 9                          CTS  45.0  9000.0       Delhi   India       0
# 10                         CTS  23.0     NaN      Mumbai   India       0
# 11                         CTS  34.0  1089.0    Calcutta   India       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
#  5   Gender   148 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.1+ KB

# %%
df.describe()
# Out:
#               Age       Salary      Gender
# count  130.000000   124.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     11.096640  2573.764683    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     32.500000  5000.000000    0.000000
# 75%     37.750000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %%
df['Company']
# Out:
# 0                            TCS
# 1                        Infosys
# 2                            TCS
# 3                        Infosys
# 4                            TCS
# 5                        Infosys
# 6                            TCS
# 7                        Infosys
# 8                            TCS
# 9                            CTS
# 10                           CTS
# 11                           CTS
# 12                           CTS
# 13                           CTS
# 14                       Infosys
# 15                           TCS
# 16                       Infosys
# 17                           TCS
# 18                           TCS
# 19                       Infosys
# 20                           TCS
# 21                       Infosys
# 22                           TCS
# 23                       Infosys
# 24                           TCS
# 25                       Infosys
# 26                           TCS
# 27                           CTS
# ...

# %%
df['Company'].value_counts()
# Out:
# TCS                          53
# Infosys                      45
# CTS                          36
# Tata Consultancy Services     2
# Congnizant                    2
# Infosys Pvt Lmt               2
# Name: Company, dtype: int64

# %%
df['Company'].replace({'Tata Consultancy Services':'TCS','Infosys Pvt Lmt':'Infosys','Congnizant':'CTS'},inplace=True)

# %%
df['Company'].value_counts()
# Out:
# TCS        55
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %%
df['Company'].isnull().sum()
# Out:
# 8

# %%
df['Company'].mode()[0]
# Out:
# 'TCS'

# %%
df['Company'].fillna(df['Company'].mode()[0],inplace=True)

# %%
df['Company'].isnull().sum()
# Out:
# 0

# %%
df['Company'].value_counts()
# Out:
# TCS        63
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %%
df['Age'].min()
# Out:
# 0.0

# %%
df['Age'].max()
# Out:
# 54.0

# %%
df['Age'].isnull().sum()
# Out:
# 18

# %%
round(df['Age'].mean(),1)
# Out:
# 30.5

# %%
df['Age'].fillna(round(df['Age'].mean(),1),inplace=True)

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %%
df['Salary'].isnull().sum()
# Out:
# 24

# %%
round(df['Salary'].mean(),3)
# Out:
# 5312.468

# %%
df['Salary']=df['Salary'].fillna(round(df['Salary'].mean(),3))

# %%
df['Salary']
# Out:
# 0      5312.468
# 1      5312.468
# 2      2300.000
# 3      3000.000
# 4      4000.000
# 5      5000.000
# 6      6000.000
# 7      7000.000
# 8      8000.000
# 9      9000.000
# 10     5312.468
# 11     1089.000
# 12     5312.468
# 13     1234.000
# 14     3000.000
# 15     3000.000
# 16     3030.000
# 17     5000.000
# 18     5312.468
# 19     5312.468
# 20     3045.000
# 21     3184.000
# 22     4824.000
# 23     5835.000
# 24     7084.000
# 25     8943.000
# 26     8345.000
# 27     9284.000
# 28     9876.000
# 29     2034.000
# 30     7654.000
# 31     2934.000
# 32     4034.000
# 33     5034.000
# 34     8202.000
# 35     9024.000
# 36     5312.468
# 37     5312.468
# 38     2300.000
# 39     3000.000
# 40     4345.000
# 41     5000.000
# 42     6000.000
# 43     7000.000
# 44     8000.000
# 45     9000.000
# 46     5312.468
# 47     1089.000
# 48     5312.468
# 49     1234.000
# 50     3000.000
# 51     3000.000
# 52     3030.000
# 53     5000.000
# 54     6544.000
# ...

# %%
df['Country'].isnull().sum()
# Out:
# 0

# %%
df['Place'].isnull().sum()
# Out:
# 14

# %%
df
# Out:
#      Company   Age    Salary       Place Country  Gender
# 0        TCS  20.0  5312.468     Chennai   India       0
# 1    Infosys  30.0  5312.468      Mumbai   India       0
# 2        TCS  35.0  2300.000    Calcutta   India       0
# 3    Infosys  40.0  3000.000       Delhi   India       0
# 4        TCS  23.0  4000.000      Mumbai   India       0
# 5    Infosys  30.5  5000.000    Calcutta   India       0
# 6        TCS  30.5  6000.000     Chennai   India       1
# 7    Infosys  23.0  7000.000      Mumbai   India       1
# 8        TCS  34.0  8000.000    Calcutta   India       1
# 9        CTS  45.0  9000.000       Delhi   India       0
# 10       CTS  23.0  5312.468      Mumbai   India       0
# 11       CTS  34.0  1089.000    Calcutta   India       0
# 12       CTS  45.0  5312.468     Chennai   India       0
# 13       CTS  18.0  1234.000      Mumbai   India       0
# 14   Infosys  40.0  3000.000    Calcutta   India       0
# ...

# %%
df=df.dropna(subset=['Place'])

# %%
df.count()
# Out:
# Company    134
# Age        134
# Salary     134
# Place      134
# Country    134
# Gender     134
# dtype: int64

# %%
df=df.drop(columns=['Country','Gender'])

# %%
df
# Out:
#      Company   Age    Salary       Place
# 0        TCS  20.0  5312.468     Chennai
# 1    Infosys  30.0  5312.468      Mumbai
# 2        TCS  35.0  2300.000    Calcutta
# 3    Infosys  40.0  3000.000       Delhi
# 4        TCS  23.0  4000.000      Mumbai
# 5    Infosys  30.5  5000.000    Calcutta
# 6        TCS  30.5  6000.000     Chennai
# 7    Infosys  23.0  7000.000      Mumbai
# 8        TCS  34.0  8000.000    Calcutta
# 9        CTS  45.0  9000.000       Delhi
# 10       CTS  23.0  5312.468      Mumbai
# 11       CTS  34.0  1089.000    Calcutta
# 12       CTS  45.0  5312.468     Chennai
# 13       CTS  18.0  1234.000      Mumbai
# 14   Infosys  40.0  3000.000    Calcutta
# 15       TCS  23.0  3000.000       Delhi
# 16   Infosys  23.0  3030.000  Podicherry
# 17       TCS  34.0  5000.000      Cochin
# 18       TCS  22.0  5312.468     Chennai
# 19   Infosys  32.0  5312.468      Mumbai
# 20       TCS  37.0  3045.000    Calcutta
# 21   Infosys  50.0  3184.000       Delhi
# ...

# %%
def get_language(city):
    if city in ['Chennai','Podicherry']:
        return "Tamizh"
    elif city in ["Mumbai","Delhi"]:
        return "Hindi"
    elif city=="Calcutta":
        return "Bengali"
    elif city=='Cochin':
        return "Malayalam"
    elif city=='Hyderabad':
        return 'Telugu'
    else:
        return "HINDI"

# %%
df['Language']=df['Place'].apply(get_language)

# %%
df.head(20)
# Out:
#     Company   Age    Salary       Place   Language
# 0       TCS  20.0  5312.468     Chennai     Tamizh
# 1   Infosys  30.0  5312.468      Mumbai      Hindi
# 2       TCS  35.0  2300.000    Calcutta    Bengali
# 3   Infosys  40.0  3000.000       Delhi      Hindi
# 4       TCS  23.0  4000.000      Mumbai      Hindi
# 5   Infosys  30.5  5000.000    Calcutta    Bengali
# 6       TCS  30.5  6000.000     Chennai     Tamizh
# 7   Infosys  23.0  7000.000      Mumbai      Hindi
# 8       TCS  34.0  8000.000    Calcutta    Bengali
# 9       CTS  45.0  9000.000       Delhi      Hindi
# 10      CTS  23.0  5312.468      Mumbai      Hindi
# 11      CTS  34.0  1089.000    Calcutta    Bengali
# 12      CTS  45.0  5312.468     Chennai     Tamizh
# 13      CTS  18.0  1234.000      Mumbai      Hindi
# 14  Infosys  40.0  3000.000    Calcutta    Bengali
# 15      TCS  23.0  3000.000       Delhi      Hindi
# 16  Infosys  23.0  3030.000  Podicherry     Tamizh
# ...

# %%
df['Bonus']=df['Salary'].apply(lambda x: round(.2*x))

# %%
df.head(20)
# Out:
#     Company   Age    Salary       Place   Language  Bonus
# 0       TCS  20.0  5312.468     Chennai     Tamizh   1062
# 1   Infosys  30.0  5312.468      Mumbai      Hindi   1062
# 2       TCS  35.0  2300.000    Calcutta    Bengali    460
# 3   Infosys  40.0  3000.000       Delhi      Hindi    600
# 4       TCS  23.0  4000.000      Mumbai      Hindi    800
# 5   Infosys  30.5  5000.000    Calcutta    Bengali   1000
# 6       TCS  30.5  6000.000     Chennai     Tamizh   1200
# 7   Infosys  23.0  7000.000      Mumbai      Hindi   1400
# 8       TCS  34.0  8000.000    Calcutta    Bengali   1600
# 9       CTS  45.0  9000.000       Delhi      Hindi   1800
# 10      CTS  23.0  5312.468      Mumbai      Hindi   1062
# 11      CTS  34.0  1089.000    Calcutta    Bengali    218
# 12      CTS  45.0  5312.468     Chennai     Tamizh   1062
# 13      CTS  18.0  1234.000      Mumbai      Hindi    247
# 14  Infosys  40.0  3000.000    Calcutta    Bengali    600
# ...

# %%
df[df['Place']=='Chennai']
# Out:
#      Company   Age    Salary    Place Language  Bonus
# 0        TCS  20.0  5312.468  Chennai   Tamizh   1062
# 6        TCS  30.5  6000.000  Chennai   Tamizh   1200
# 12       CTS  45.0  5312.468  Chennai   Tamizh   1062
# 18       TCS  22.0  5312.468  Chennai   Tamizh   1062
# 24       TCS  30.5  7084.000  Chennai   Tamizh   1417
# 30       CTS  46.0  7654.000  Chennai   Tamizh   1531
# 50   Infosys  41.0  3000.000  Chennai   Tamizh    600
# 70   Infosys  21.0  8202.000  Chennai   Tamizh   1640
# 83       CTS  33.0  1089.000  Chennai   Tamizh    218
# 89       TCS  36.0  5000.000  Chennai   Tamizh   1000
# 95   Infosys  30.5  5835.000  Chennai   Tamizh   1167
# 107      TCS   0.0  9024.000  Chennai   Tamizh   1805
# 113  Infosys  30.5  5435.000  Chennai   Tamizh   1087
# 133      TCS  22.0  8943.000  Chennai   Tamizh   1789

# %%
df[(df['Company']=='TCS') & (df['Salary']>8000)]
# Out:
#     Company   Age  Salary     Place Language  Bonus
# 26      TCS  34.0  8345.0  Calcutta  Bengali   1669
# 71      TCS  34.0  9024.0    Mumbai    Hindi   1805
# 98      TCS  33.0  8345.0     Delhi    Hindi   1669
# 107     TCS   0.0  9024.0   Chennai   Tamizh   1805
# 133     TCS  22.0  8943.0   Chennai   Tamizh   1789
# 134     TCS  31.0  8345.0    Mumbai    Hindi   1669
# 143     TCS  33.0  9024.0  Calcutta  Bengali   1805

# %%
df[(df['Company']=='TCS') & (df['Salary']>8000) & (df['Place'] != 'Mumbai')]
# Out:
#     Company   Age  Salary     Place Language  Bonus
# 26      TCS  34.0  8345.0  Calcutta  Bengali   1669
# 98      TCS  33.0  8345.0     Delhi    Hindi   1669
# 107     TCS   0.0  9024.0   Chennai   Tamizh   1805
# 133     TCS  22.0  8943.0   Chennai   Tamizh   1789
# 143     TCS  33.0  9024.0  Calcutta  Bengali   1805

# %%
df[(df['Language']=='Tamizh') | (df['Language']=='Telugu')]
# Out:
#      Company   Age    Salary       Place Language  Bonus
# 0        TCS  20.0  5312.468     Chennai   Tamizh   1062
# 6        TCS  30.5  6000.000     Chennai   Tamizh   1200
# 12       CTS  45.0  5312.468     Chennai   Tamizh   1062
# 16   Infosys  23.0  3030.000  Podicherry   Tamizh    606
# 18       TCS  22.0  5312.468     Chennai   Tamizh   1062
# 24       TCS  30.5  7084.000     Chennai   Tamizh   1417
# 30       CTS  46.0  7654.000     Chennai   Tamizh   1531
# 37       TCS  35.0  5312.468   Hyderabad   Telugu   1062
# 45       CTS  46.0  9000.000   Hyderabad   Telugu   1800
# 50   Infosys  41.0  3000.000     Chennai   Tamizh    600
# 57   Infosys  51.0  3184.000   Hyderabad   Telugu    637
# 65       CTS  31.0  2034.000   Hyderabad   Telugu    407
# 70   Infosys  21.0  8202.000     Chennai   Tamizh   1640
# 77   Infosys  30.5  5000.000   Hyderabad   Telugu   1000
# 83       CTS  33.0  1089.000     Chennai   Tamizh    218
# ...

# %%
df.head()
# Out:
#    Company   Age    Salary     Place Language  Bonus
# 0      TCS  20.0  5312.468   Chennai   Tamizh   1062
# 1  Infosys  30.0  5312.468    Mumbai    Hindi   1062
# 2      TCS  35.0  2300.000  Calcutta  Bengali    460
# 3  Infosys  40.0  3000.000     Delhi    Hindi    600
# 4      TCS  23.0  4000.000    Mumbai    Hindi    800

# %%
df.iloc[100:110, :]
# Out:
#      Company   Age    Salary      Place   Language  Bonus
# 109      TCS  33.0  5312.468   Calcutta    Bengali   1062
# 110      TCS  33.0  2300.000      Delhi      Hindi    460
# 111  Infosys   0.0  3234.000     Mumbai      Hindi    647
# 112      TCS  22.0  4324.000     Cochin  Malayalam    865
# 113  Infosys  30.5  5435.000    Chennai     Tamizh   1087
# 114      TCS  30.5  5555.000     Mumbai      Hindi   1111
# 115  Infosys  22.0  8787.000   Calcutta    Bengali   1757
# 119      CTS  33.0  1089.000      Noida      HINDI    218
# 120      CTS  44.0  5312.468  Hyderabad     Telugu   1062
# 121      CTS   0.0  1234.000   Calcutta    Bengali    247

# %%
df=df.reset_index()

# %%
df.iloc[100:110, :]
# Out:
#      index  Company   Age    Salary      Place   Language  Bonus
# 100    109      TCS  33.0  5312.468   Calcutta    Bengali   1062
# 101    110      TCS  33.0  2300.000      Delhi      Hindi    460
# 102    111  Infosys   0.0  3234.000     Mumbai      Hindi    647
# 103    112      TCS  22.0  4324.000     Cochin  Malayalam    865
# 104    113  Infosys  30.5  5435.000    Chennai     Tamizh   1087
# 105    114      TCS  30.5  5555.000     Mumbai      Hindi   1111
# 106    115  Infosys  22.0  8787.000   Calcutta    Bengali   1757
# 107    119      CTS  33.0  1089.000      Noida      HINDI    218
# 108    120      CTS  44.0  5312.468  Hyderabad     Telugu   1062
# 109    121      CTS   0.0  1234.000   Calcutta    Bengali    247

# %%
df.iloc[100:110, 1:4]
# Out:
#      Company   Age    Salary
# 100      TCS  33.0  5312.468
# 101      TCS  33.0  2300.000
# 102  Infosys   0.0  3234.000
# 103      TCS  22.0  4324.000
# 104  Infosys  30.5  5435.000
# 105      TCS  30.5  5555.000
# 106  Infosys  22.0  8787.000
# 107      CTS  33.0  1089.000
# 108      CTS  44.0  5312.468
# 109      CTS   0.0  1234.000

# %%
df.loc[100:110,['Place','Company','Salary','Bonus']]
# Out:
#          Place  Company    Salary  Bonus
# 100   Calcutta      TCS  5312.468   1062
# 101      Delhi      TCS  2300.000    460
# 102     Mumbai  Infosys  3234.000    647
# 103     Cochin      TCS  4324.000    865
# 104    Chennai  Infosys  5435.000   1087
# 105     Mumbai      TCS  5555.000   1111
# 106   Calcutta  Infosys  8787.000   1757
# 107      Noida      CTS  1089.000    218
# 108  Hyderabad      CTS  5312.468   1062
# 109   Calcutta      CTS  1234.000    247
# 110     Mumbai  Infosys  3234.000    647

# %%
df['total_salary']=df['Salary']+df['Bonus']

# %%
df.loc[100:110,['Place','Company','Salary','Bonus','total_salary']]
# Out:
#          Place  Company    Salary  Bonus  total_salary
# 100   Calcutta      TCS  5312.468   1062      6374.468
# 101      Delhi      TCS  2300.000    460      2760.000
# 102     Mumbai  Infosys  3234.000    647      3881.000
# 103     Cochin      TCS  4324.000    865      5189.000
# 104    Chennai  Infosys  5435.000   1087      6522.000
# 105     Mumbai      TCS  5555.000   1111      6666.000
# 106   Calcutta  Infosys  8787.000   1757     10544.000
# 107      Noida      CTS  1089.000    218      1307.000
# 108  Hyderabad      CTS  5312.468   1062      6374.468
# 109   Calcutta      CTS  1234.000    247      1481.000
# 110     Mumbai  Infosys  3234.000    647      3881.000

# %%
df
# Out:
#      index  Company   Age    Salary       Place   Language  Bonus  \
# 0        0      TCS  20.0  5312.468     Chennai     Tamizh   1062
# 1        1  Infosys  30.0  5312.468      Mumbai      Hindi   1062
# 2        2      TCS  35.0  2300.000    Calcutta    Bengali    460
# 3        3  Infosys  40.0  3000.000       Delhi      Hindi    600
# 4        4      TCS  23.0  4000.000      Mumbai      Hindi    800
# 5        5  Infosys  30.5  5000.000    Calcutta    Bengali   1000
# 6        6      TCS  30.5  6000.000     Chennai     Tamizh   1200
# 7        7  Infosys  23.0  7000.000      Mumbai      Hindi   1400
# 8        8      TCS  34.0  8000.000    Calcutta    Bengali   1600
# 9        9      CTS  45.0  9000.000       Delhi      Hindi   1800
# 10      10      CTS  23.0  5312.468      Mumbai      Hindi   1062
# 11      11      CTS  34.0  1089.000    Calcutta    Bengali    218
# 12      12      CTS  45.0  5312.468     Chennai     Tamizh   1062
# ...

# %%
df=df.rename(columns={'Place':'City','total_salary':'Revised_Salary'})

# %%
df=df.drop(columns=['index'])

# %%
df
# Out:
#      Company   Age    Salary        City   Language  Bonus  Revised_Salary
# 0        TCS  20.0  5312.468     Chennai     Tamizh   1062        6374.468
# 1    Infosys  30.0  5312.468      Mumbai      Hindi   1062        6374.468
# 2        TCS  35.0  2300.000    Calcutta    Bengali    460        2760.000
# 3    Infosys  40.0  3000.000       Delhi      Hindi    600        3600.000
# 4        TCS  23.0  4000.000      Mumbai      Hindi    800        4800.000
# 5    Infosys  30.5  5000.000    Calcutta    Bengali   1000        6000.000
# 6        TCS  30.5  6000.000     Chennai     Tamizh   1200        7200.000
# 7    Infosys  23.0  7000.000      Mumbai      Hindi   1400        8400.000
# 8        TCS  34.0  8000.000    Calcutta    Bengali   1600        9600.000
# 9        CTS  45.0  9000.000       Delhi      Hindi   1800       10800.000
# 10       CTS  23.0  5312.468      Mumbai      Hindi   1062        6374.468
# ...

# %%
df.groupby('Company')['Salary'].min()
# Out:
# Company
# CTS        1089.0
# Infosys    3000.0
# TCS        2300.0
# Name: Salary, dtype: float64

# %%
df.groupby('Company')['Salary'].max()
# Out:
# Company
# CTS        9876.0
# Infosys    8943.0
# TCS        9024.0
# Name: Salary, dtype: float64

# %%
df.groupby('Company')['Salary'].mean()
# Out:
# Company
# CTS        4505.819429
# Infosys    5233.997091
# TCS        5395.912945
# Name: Salary, dtype: float64

# %%
df.groupby('Company')['Salary'].agg(['min','max','mean'])
# Out:
#             min     max         mean
# Company
# CTS      1089.0  9876.0  4505.819429
# Infosys  3000.0  8943.0  5233.997091
# TCS      2300.0  9024.0  5395.912945

# %%
df.groupby(['Company','City'])['Salary'].agg(['min','max','mean'])
# Out:
#                          min       max         mean
# Company City
# CTS     Calcutta    1089.000  9284.000  3771.419429
#         Chennai     1089.000  7654.000  4685.156000
#         Cochin      1234.000  5312.468  2903.367000
#         Delhi       9000.000  9284.000  9142.000000
#         Hyderabad   2034.000  9000.000  5448.822667
#         Mumbai      1089.000  9876.000  4135.087200
#         Noida       1089.000  2934.000  2011.500000
#         Podicherry  2034.000  9284.000  5659.000000
#         Pune        5312.468  9000.000  7156.234000
# Infosys Bhopal      7000.000  7000.000  7000.000000
#         Calcutta    3000.000  8943.000  5626.769818
#         Chennai     3000.000  8202.000  5618.000000
#         Cochin      3000.000  8202.000  6578.600000
#         Delhi       3000.000  5312.468  3760.744667
#         Hyderabad   3184.000  5000.000  4072.666667
#         Mumbai      3000.000  8943.000  5260.494667
#         Noida       5098.000  5098.000  5098.000000
# ...

# %%
df
# Out:
#      Company   Age    Salary        City   Language  Bonus  Revised_Salary
# 0        TCS  20.0  5312.468     Chennai     Tamizh   1062        6374.468
# 1    Infosys  30.0  5312.468      Mumbai      Hindi   1062        6374.468
# 2        TCS  35.0  2300.000    Calcutta    Bengali    460        2760.000
# 3    Infosys  40.0  3000.000       Delhi      Hindi    600        3600.000
# 4        TCS  23.0  4000.000      Mumbai      Hindi    800        4800.000
# 5    Infosys  30.5  5000.000    Calcutta    Bengali   1000        6000.000
# 6        TCS  30.5  6000.000     Chennai     Tamizh   1200        7200.000
# 7    Infosys  23.0  7000.000      Mumbai      Hindi   1400        8400.000
# 8        TCS  34.0  8000.000    Calcutta    Bengali   1600        9600.000
# 9        CTS  45.0  9000.000       Delhi      Hindi   1800       10800.000
# 10       CTS  23.0  5312.468      Mumbai      Hindi   1062        6374.468
# ...

# %%
df.sort_values(by=['Revised_Salary','Age'])
# Out:
#      Company   Age    Salary        City   Language  Bonus  Revised_Salary
# 41       CTS  32.0  1089.000      Mumbai      Hindi    218        1307.000
# 74       CTS  33.0  1089.000     Chennai     Tamizh    218        1307.000
# 107      CTS  33.0  1089.000       Noida      HINDI    218        1307.000
# 11       CTS  34.0  1089.000    Calcutta    Bengali    218        1307.000
# 109      CTS   0.0  1234.000    Calcutta    Bengali    247        1481.000
# 76       CTS  17.0  1234.000    Calcutta    Bengali    247        1481.000
# 13       CTS  18.0  1234.000      Mumbai      Hindi    247        1481.000
# 43       CTS  19.0  1234.000      Cochin  Malayalam    247        1481.000
# 92       CTS   0.0  2034.000  Podicherry     Tamizh    407        2441.000
# 56       CTS  31.0  2034.000   Hyderabad     Telugu    407        2441.000
# 123      CTS  31.0  2034.000      Mumbai      Hindi    407        2441.000
# ...

# %%
df=df.sort_values(by=['Revised_Salary','Age'],ascending=False)

# %%
df
# Out:
#      Company   Age    Salary        City   Language  Bonus  Revised_Salary
# 28       CTS  23.0  9876.000      Mumbai      Hindi   1975       11851.000
# 27       CTS  45.0  9284.000       Delhi      Hindi   1857       11141.000
# 90       CTS  44.0  9284.000  Podicherry     Tamizh   1857       11141.000
# 121      CTS  40.0  9284.000    Calcutta    Bengali   1857       11141.000
# 62       TCS  34.0  9024.000      Mumbai      Hindi   1805       10829.000
# 129      TCS  33.0  9024.000    Calcutta    Bengali   1805       10829.000
# 98       TCS   0.0  9024.000     Chennai     Tamizh   1805       10829.000
# 39       CTS  46.0  9000.000   Hyderabad     Telugu   1800       10800.000
# 9        CTS  45.0  9000.000       Delhi      Hindi   1800       10800.000
# 72       CTS  43.0  9000.000        Pune      HINDI   1800       10800.000
# 25   Infosys  23.0  8943.000      Mumbai      Hindi   1789       10732.000
# ...

# %%
df.to_csv(r'C:\Users\DELL\Desktop\test\Company_modified.csv',index=False)
